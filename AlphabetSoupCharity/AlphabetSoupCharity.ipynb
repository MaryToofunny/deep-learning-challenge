# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from google.colab import files

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
filtered_df = application_df.drop(columns=["NAME", "EIN"])
filtered_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
filtered_cat = filtered_df.dtypes[filtered_df.dtypes == "object"].index.tolist()
filtered_cat
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT',
#  'SPECIAL_CONSIDERATIONS']

# %%
filtered_df[filtered_cat].nunique()
# Out:
# APPLICATION_TYPE          17
# AFFILIATION                6
# CLASSIFICATION            71
# USE_CASE                   5
# ORGANIZATION               4
# INCOME_AMT                 9
# SPECIAL_CONSIDERATIONS     2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type = filtered_df['APPLICATION_TYPE'].value_counts().reset_index()
app_type
# Out:
#    index  APPLICATION_TYPE
# 0     T3             27037
# 1     T4              1542
# 2     T6              1216
# 3     T5              1173
# 4    T19              1065
# 5     T8               737
# 6     T7               725
# 7    T10               528
# 8     T9               156
# 9    T13                66
# 10   T12                27
# 11    T2                16
# 12   T25                 3
# 13   T14                 3
# 14   T29                 2
# 15   T15                 2
# 16   T17                 1

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = []
application_types_to_replace = app_type[app_type['APPLICATION_TYPE'] <= 156]['index']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = filtered_df['CLASSIFICATION'].value_counts().reset_index()
class_count
# Out:
#     index  CLASSIFICATION
# 0   C1000           17326
# 1   C2000            6074
# 2   C1200            4837
# 3   C3000            1918
# 4   C2100            1883
# ..    ...             ...
# 66  C4120               1
# 67  C8210               1
# 68  C2561               1
# 69  C4500               1
# 70  C2150               1
#
# [71 rows x 2 columns]

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_count_filtered = []
class_count_filtered = class_count[class_count['CLASSIFICATION'] > 1]
class_count_filtered
# Out:
#     index  CLASSIFICATION
# 0   C1000           17326
# 1   C2000            6074
# 2   C1200            4837
# 3   C3000            1918
# 4   C2100            1883
# 5   C7000             777
# 6   C1700             287
# 7   C4000             194
# 8   C5000             116
# 9   C1270             114
# 10  C2700             104
# 11  C2800              95
# 12  C7100              75
# 13  C1300              58
# 14  C1280              50
# 15  C1230              36
# 16  C1400              34
# 17  C7200              32
# 18  C2300              32
# 19  C1240              30
# 20  C8000              20
# 21  C7120              18
# 22  C1500              16
# 23  C1800              15
# 24  C6000              15
# 25  C1250              14
# 26  C8200              11
# 27  C1238              10
# 28  C1278              10
# 29  C1235               9
# 30  C1237               9
# 31  C7210               7
# 32  C2400               6
# 33  C1720               6
# 34  C4100               6
# 35  C1257               5
# 36  C1600               5
# 37  C1260               3
# 38  C2710               3
# 39     C0               3
# 40  C3200               2
# 41  C1234               2
# 42  C1246               2
# 43  C1267               2
# 44  C1256               2

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = []
classifications_to_replace = class_count[class_count['CLASSIFICATION'] < 1883]['index']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
filtered_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numerical_df = pd.get_dummies(filtered_df)
numerical_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                     1
# 1           1    108590              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  \
# 0                         0                     0                     0  ...
# 1                         0                     0                     0  ...
# 2                         0                     0                     0  ...
# 3                         0                     0                     0  ...
# 4                         0                     0                     0  ...
# ...                     ...                   ...                   ...  ...
# 34294                     0                     0                     0  ...
# 34295                     0                     0                     0  ...
# 34296                     0                     0                     0  ...
# 34297                     0                     0                     0  ...
# 34298                     0                     0                     0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = numerical_df["IS_SUCCESSFUL"].values
X = numerical_df.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# <ipython-input-16-775795f8e043>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = numerical_df.drop(["IS_SUCCESSFUL"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="ReLU")
)


# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="ReLU"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 80)                9360
#
#  dense_4 (Dense)             (None, 30)                2430
#
#  dense_5 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 11,821
# Trainable params: 11,821
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5755 - accuracy: 0.7207
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5542 - accuracy: 0.7304
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5514 - accuracy: 0.7305
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5484 - accuracy: 0.7315
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5476 - accuracy: 0.7338
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5455 - accuracy: 0.7325
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5445 - accuracy: 0.7332
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5442 - accuracy: 0.7322
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5434 - accuracy: 0.7332
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7343
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5417 - accuracy: 0.7350
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7353
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5407 - accuracy: 0.7356
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5396 - accuracy: 0.7361
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5393 - accuracy: 0.7365
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7360
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7368
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7370
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5379 - accuracy: 0.7370
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7380
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7375
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7377
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5369 - accuracy: 0.7381
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7383
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7373
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7386
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7382
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7394
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5358 - accuracy: 0.7379
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7387
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5347 - accuracy: 0.7392
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5351 - accuracy: 0.7400
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7395
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7388
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7399
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7404
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7386
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5334 - accuracy: 0.7399
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7404
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7399
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7397
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7402
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5327 - accuracy: 0.7404
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5327 - accuracy: 0.7411
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7404
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7399
# Epoch 47/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7409
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5319 - accuracy: 0.7401
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7405
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.7403
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7406
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7404
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7413
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5311 - accuracy: 0.7415
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7404
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7413
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7409
# Epoch 58/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5307 - accuracy: 0.7409
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7408
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5309 - accuracy: 0.7410
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5305 - accuracy: 0.7414
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5307 - accuracy: 0.7418
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5304 - accuracy: 0.7413
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7414
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5303 - accuracy: 0.7409
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5306 - accuracy: 0.7422
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5303 - accuracy: 0.7409
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5301 - accuracy: 0.7419
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5302 - accuracy: 0.7413
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5303 - accuracy: 0.7422
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5301 - accuracy: 0.7414
# Epoch 72/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5296 - accuracy: 0.7424
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5297 - accuracy: 0.7426
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5301 - accuracy: 0.7427
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5295 - accuracy: 0.7410
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5296 - accuracy: 0.7418
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5295 - accuracy: 0.7432
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5295 - accuracy: 0.7414
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5294 - accuracy: 0.7421
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5295 - accuracy: 0.7420
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5292 - accuracy: 0.7413
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5292 - accuracy: 0.7416
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5289 - accuracy: 0.7420
# Epoch 84/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5290 - accuracy: 0.7415
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5287 - accuracy: 0.7417
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5288 - accuracy: 0.7428
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5292 - accuracy: 0.7416
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5286 - accuracy: 0.7424
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5284 - accuracy: 0.7428
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5287 - accuracy: 0.7425
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5290 - accuracy: 0.7432
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5288 - accuracy: 0.7417
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5290 - accuracy: 0.7430
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5285 - accuracy: 0.7436
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5284 - accuracy: 0.7428
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5285 - accuracy: 0.7424
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5284 - accuracy: 0.7430
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5284 - accuracy: 0.7429
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5282 - accuracy: 0.7419
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5282 - accuracy: 0.7425

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5625 - accuracy: 0.7265 - 350ms/epoch - 1ms/step
# Loss: 0.5624915361404419, Accuracy: 0.7265306115150452

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
# Out:
# <Axes: >

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <Axes: >

# %%
#Attemp2 3 layers

# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="ReLU")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="ReLU"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="ReLU"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 80)                9360
#
#  dense_7 (Dense)             (None, 30)                2430
#
#  dense_8 (Dense)             (None, 10)                310
#
#  dense_9 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 12,111
# Trainable params: 12,111
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5276 - accuracy: 0.7428
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5271 - accuracy: 0.7423
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5265 - accuracy: 0.7426
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5269 - accuracy: 0.7434
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7440
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5260 - accuracy: 0.7431
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5270 - accuracy: 0.7431
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5263 - accuracy: 0.7436
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5265 - accuracy: 0.7424
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5265 - accuracy: 0.7426
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5275 - accuracy: 0.7422
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5263 - accuracy: 0.7430
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5263 - accuracy: 0.7425
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5263 - accuracy: 0.7428
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5266 - accuracy: 0.7435
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5261 - accuracy: 0.7425
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5264 - accuracy: 0.7439
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5267 - accuracy: 0.7418
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5263 - accuracy: 0.7430
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5256 - accuracy: 0.7443
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5261 - accuracy: 0.7434
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5262 - accuracy: 0.7431
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5257 - accuracy: 0.7442
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5261 - accuracy: 0.7435
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5255 - accuracy: 0.7432
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5263 - accuracy: 0.7428
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5258 - accuracy: 0.7437
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5256 - accuracy: 0.7424
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5259 - accuracy: 0.7430
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5255 - accuracy: 0.7431
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5258 - accuracy: 0.7437
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5258 - accuracy: 0.7432
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5260 - accuracy: 0.7435
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5257 - accuracy: 0.7436
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5252 - accuracy: 0.7434
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5256 - accuracy: 0.7435
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5257 - accuracy: 0.7435
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5253 - accuracy: 0.7433
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5252 - accuracy: 0.7444
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5256 - accuracy: 0.7432
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5254 - accuracy: 0.7441
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5252 - accuracy: 0.7440
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5250 - accuracy: 0.7438
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5253 - accuracy: 0.7435
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5253 - accuracy: 0.7436
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5248 - accuracy: 0.7450
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5252 - accuracy: 0.7437
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5252 - accuracy: 0.7445
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5257 - accuracy: 0.7436
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5255 - accuracy: 0.7439
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5250 - accuracy: 0.7439
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5249 - accuracy: 0.7441
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5256 - accuracy: 0.7435
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5250 - accuracy: 0.7441
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5251 - accuracy: 0.7434
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5253 - accuracy: 0.7442
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5255 - accuracy: 0.7439
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5248 - accuracy: 0.7440
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5246 - accuracy: 0.7444
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5250 - accuracy: 0.7435
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5249 - accuracy: 0.7430
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5254 - accuracy: 0.7433
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5250 - accuracy: 0.7437
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5248 - accuracy: 0.7440
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5244 - accuracy: 0.7440
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5244 - accuracy: 0.7445
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5244 - accuracy: 0.7441
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5251 - accuracy: 0.7442
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5247 - accuracy: 0.7449
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5243 - accuracy: 0.7442
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5244 - accuracy: 0.7439
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5252 - accuracy: 0.7436
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5245 - accuracy: 0.7437
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5244 - accuracy: 0.7430
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5246 - accuracy: 0.7439
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5244 - accuracy: 0.7446
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5246 - accuracy: 0.7443
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5255 - accuracy: 0.7435
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5260 - accuracy: 0.7442
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5242 - accuracy: 0.7442
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5247 - accuracy: 0.7442
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5242 - accuracy: 0.7440
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5242 - accuracy: 0.7438
# Epoch 84/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5246 - accuracy: 0.7444
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5240 - accuracy: 0.7434
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5243 - accuracy: 0.7442
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5247 - accuracy: 0.7439
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5243 - accuracy: 0.7443
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5244 - accuracy: 0.7441
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5243 - accuracy: 0.7437
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5244 - accuracy: 0.7438
# Epoch 92/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5250 - accuracy: 0.7432
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5243 - accuracy: 0.7439
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5239 - accuracy: 0.7441
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5243 - accuracy: 0.7444
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5241 - accuracy: 0.7444
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5248 - accuracy: 0.7448
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5242 - accuracy: 0.7434
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5237 - accuracy: 0.7445
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5243 - accuracy: 0.7434

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5852 - accuracy: 0.7292 - 340ms/epoch - 1ms/step
# Loss: 0.5851761102676392, Accuracy: 0.7292128205299377

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
# Out:
# <Axes: >

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <Axes: >

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity.h5')  
files.download('AlphabetSoupCharity.h5')
